# %% [markdown]
# <a href="https://colab.research.google.com/github/doyeonKoo/esaa/blob/main/grouping%EF%BC%BFoccupation%EF%BC%BFExercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Occupation

# %% [markdown]
# ### Introduction:
#
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user).

# %% [markdown]
# ### Step 3. Assign it to a variable called users.

# %%
users = pd.read_csv("https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user",
                    sep='|')
users = pd.DataFrame(users)
users.head()
# Out:
#    user_id  age gender  occupation zip_code
# 0        1   24      M  technician    85711
# 1        2   53      F       other    94043
# 2        3   23      M      writer    32067
# 3        4   24      M  technician    43537
# 4        5   33      F       other    15213

# %% [markdown]
# ### Step 4. Discover what is the mean age per occupation

# %%
occupation = users.groupby('occupation')
occupation['age'].mean()
# Out:
# occupation
# administrator    38.746835
# artist           31.392857
# doctor           43.571429
# educator         42.010526
# engineer         36.388060
# entertainment    29.222222
# executive        38.718750
# healthcare       41.562500
# homemaker        32.571429
# lawyer           36.750000
# librarian        40.000000
# marketing        37.615385
# none             26.555556
# other            34.523810
# programmer       33.121212
# retired          63.071429
# salesman         35.666667
# scientist        35.548387
# student          22.081633
# technician       33.148148
# writer           36.311111
# Name: age, dtype: float64

# %% [markdown]
# ### Step 5. Discover the Male ratio per occupation and sort it from the most to the least

# %%
occupation['gender'=='M']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-31-3d90a025b4b3> in <cell line: 1>()
# ----> 1 occupation['gender'=='M']
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/generic.py in __getitem__(self, key)
#    1414                 stacklevel=find_stack_level(),
#    1415             )
# -> 1416         return super().__getitem__(key)
#    1417
#    1418     def _gotitem(self, key, ndim: int, subset=None):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/base.py in __getitem__(self, key)
#     246         else:
#     247             if key not in self.obj:
# --> 248                 raise KeyError(f"Column not found: {key}")
#     249             subset = self.obj[key]
#     250             ndim = subset.ndim
#
# KeyError: 'Column not found: False'

# %% [markdown]
# ### Step 6. For each occupation, calculate the minimum and maximum ages

# %%
print('직업별 최소나이:\n',occupation.min('age'), '직업별 최대나이:\n:', occupation.max('age'))
# Out:
# 직업별 최소나이:
#                 user_id  age
# occupation
# administrator        7   21
# artist              23   19
# doctor             138   28
# educator            13   23
# engineer            25   22
# entertainment       16   15
# executive            6   22
# healthcare          60   22
# homemaker           20   20
# lawyer              10   21
# librarian           19   23
# marketing           46   24
# none                57   11
# other                2   13
# programmer          17   20
# retired            106   51
# salesman           112   18
# scientist           14   23
# student              9    7
# technician           1   21
# writer               3   18 직업별 최대나이:
# :                user_id  age
# occupation
# administrator      940   70
# artist             920   48
# doctor             935   64
# educator           937   63
# engineer           934   70
# entertainment      926   50
# executive          901   69
# healthcare         910   62
# ...

# %% [markdown]
# ### Step 7. For each combination of occupation and gender, calculate the mean age

# %%
occ_gen = users.groupby(by=['occupation', 'gender'])
occ_gen.head()
occ_gen.mean('age')
# Out:
#                          user_id        age
# occupation    gender
# administrator F       443.944444  40.638889
#               M       420.069767  37.162791
# artist        F       432.153846  30.307692
#               M       469.000000  32.333333
# doctor        M       533.714286  43.571429
# educator      F       454.730769  39.115385
#               M       471.492754  43.101449
# engineer      F       806.500000  29.500000
#               M       445.553846  36.600000
# entertainment F       780.000000  31.000000
#               M       350.250000  29.000000
# executive     F       373.000000  44.000000
#               M       427.413793  38.172414
# healthcare    F       568.454545  39.818182
#               M       354.000000  45.400000
# homemaker     F       367.166667  34.166667
#               M       898.000000  23.000000
# lawyer        F       285.000000  39.500000
#               M       373.900000  36.200000
# librarian     F       449.137931  40.000000
# ...

# %% [markdown]
# ### Step 8.  For each occupation present the percentage of women and men

# %%
occ_gen = users.groupby(['occupation', 'gender']).agg({'gender': 'count'})

total = users.groupby(['occupation']).count()

occ_gen = gender_count.div(total, level = "occupation")
occ_gen.loc[:, 'gender']
# Out:
# occupation     gender
# administrator  F         0.455696
#                M         0.544304
# artist         F         0.464286
#                M         0.535714
# doctor         M         1.000000
# educator       F         0.273684
#                M         0.726316
# engineer       F         0.029851
#                M         0.970149
# entertainment  F         0.111111
#                M         0.888889
# executive      F         0.093750
#                M         0.906250
# healthcare     F         0.687500
#                M         0.312500
# homemaker      F         0.857143
#                M         0.142857
# lawyer         F         0.166667
#                M         0.833333
# librarian      F         0.568627
#                M         0.431373
# marketing      F         0.384615
#                M         0.615385
# none           F         0.444444
#                M         0.555556
# other          F         0.342857
#                M         0.657143
# ...
